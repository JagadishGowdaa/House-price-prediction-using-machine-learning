# %%
import pandas as pd
import numpy as np
from sklearn import linear_model
from sklearn.model_selection import train_test_split

# %%
data_source="/content/sample_data/california_housing_test.csv"
dt=pd.read_csv(data_source)
print(dt)
# Out:
#       longitude  latitude  ...  median_income  median_house_value
# 0       -122.05     37.37  ...         6.6085            344700.0
# 1       -118.30     34.26  ...         3.5990            176500.0
# 2       -117.81     33.78  ...         5.7934            270500.0
# 3       -118.36     33.82  ...         6.1359            330000.0
# 4       -119.67     36.33  ...         2.9375             81700.0
# ...         ...       ...  ...            ...                 ...
# 2995    -119.86     34.42  ...         1.1790            225000.0
# 2996    -118.14     34.06  ...         3.3906            237200.0
# 2997    -119.70     36.30  ...         2.2895             62000.0
# 2998    -117.12     34.10  ...         3.2708            162500.0
# 2999    -119.63     34.42  ...         8.5608            500001.0
#
# [3000 rows x 9 columns]

# %%
dt.describe()
# Out:
#          longitude    latitude  ...  median_income  median_house_value
# count  3000.000000  3000.00000  ...    3000.000000          3000.00000
# mean   -119.589200    35.63539  ...       3.807272        205846.27500
# std       1.994936     2.12967  ...       1.854512        113119.68747
# min    -124.180000    32.56000  ...       0.499900         22500.00000
# 25%    -121.810000    33.93000  ...       2.544000        121200.00000
# 50%    -118.485000    34.27000  ...       3.487150        177650.00000
# 75%    -118.020000    37.69000  ...       4.656475        263975.00000
# max    -114.490000    41.92000  ...      15.000100        500001.00000
#
# [8 rows x 9 columns]

# %%
y=dt.drop(['longitude','latitude','housing_median_age','total_rooms','total_bedrooms','population','households','median_income'	],axis=1)
y.describe()
# Out:
#        median_house_value
# count          3000.00000
# mean         205846.27500
# std          113119.68747
# min           22500.00000
# 25%          121200.00000
# 50%          177650.00000
# 75%          263975.00000
# max          500001.00000

# %%
x=dt.drop(['median_house_value'],axis=1)
x.describe()
# Out:
#          longitude    latitude  ...  households  median_income
# count  3000.000000  3000.00000  ...  3000.00000    3000.000000
# mean   -119.589200    35.63539  ...   489.91200       3.807272
# std       1.994936     2.12967  ...   365.42271       1.854512
# min    -124.180000    32.56000  ...     2.00000       0.499900
# 25%    -121.810000    33.93000  ...   273.00000       2.544000
# 50%    -118.485000    34.27000  ...   409.50000       3.487150
# 75%    -118.020000    37.69000  ...   597.25000       4.656475
# max    -114.490000    41.92000  ...  4930.00000      15.000100
#
# [8 rows x 8 columns]

# %%
from sklearn.linear_model import LinearRegression
reg=linear_model.LinearRegression()
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.33,random_state=42)
reg.fit(x_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
print(reg.coef_)
# Out:
# [[-4.21103906e+04 -4.18698541e+04  1.20079087e+03 -8.16146276e+00
#    8.91475499e+01 -3.88772190e+01  7.11649736e+01  3.99176400e+04]]

# %%
y_pred=reg.predict(x_test)
print(y_pred)
# Out:
# [[ 124245.53938307]
#  [ 142482.43132867]
#  [ 245497.81590905]
#  [ 205624.18966325]
#  [ 193200.23890922]
#  [ 173827.27809857]
#  [ 229835.82317991]
#  [ 162611.408574  ]
#  [  67332.1222053 ]
#  [ 199759.78161697]
#  [ 160594.11716372]
#  [ 219180.71470181]
#  [  31753.17424831]
#  [ 270752.02833332]
#  [ 137499.99224858]
#  [ 345285.42672905]
#  [  27393.47992227]
#  [ 115984.80854656]
#  [ 340376.36575807]
#  [ 238328.04717243]
#  [ 249935.24236645]
#  [ 173011.02279773]
#  [ 363194.29703136]
#  [ 120618.05086377]
#  [ 150808.0211248 ]
#  [ 254641.32740913]
#  [ 209360.01371383]
#  [  53451.82637921]
#  [ 304536.34445971]
#  [ 152445.49812096]
#  [ 334549.6566614 ]
#  [ 119718.15629626]
#  [ 124666.25987056]
#  [ 260750.19914025]
#  [ 206136.63853662]
#  [ 331774.92457119]
#  [ 157305.0078064 ]
#  [ 237888.39307032]
#  [ 242759.5486852 ]
#  [ 288645.20428799]
#  [ 186550.14480732]
#  [  37707.05232457]
#  [ 179884.04903594]
#  [  98331.91895786]
#  [ 122769.88000034]
# ...

# %%
from sklearn.metrics import mean_squared_error
print(mean_squared_error(y_pred,y_test))
# Out:
# 5093367920.294453
